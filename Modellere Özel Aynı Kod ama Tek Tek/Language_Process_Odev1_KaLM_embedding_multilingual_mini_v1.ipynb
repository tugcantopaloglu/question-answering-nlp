# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.8 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
from datasets import Dataset
import pandas as pd
df = pd.read_csv("selected_questions_answers.csv")
dataset = Dataset.from_pandas(df)
selected_questions = dataset['Question']
selected_answers = dataset['Answer']

# %%
# ornek soru ve cevap
print("Örnek Soru:", selected_questions[999])
print("Örnek Cevap:", selected_answers[999])
# Out:
# Örnek Soru: En güçlü konuşma biçimini içeren cümleyi seçin.  (1) Fırtına bir canavar gibi şiddetleniyordu. (2) Fırtına bir aslan kadar vahşiydi. (3) Fırtına bir canavar kadar şiddetliydi. (4) Fırtına vahşi bir ejderhaydı.
# Örnek Cevap: 4

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# modeli yükleme ve vektör çıkartma
def get_model_and_tokenizer(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name).to('cuda')
    return tokenizer, model

# temsil çıkarma işlevi
def get_embeddings(texts, tokenizer, model):
    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True).to('cuda')
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state[:, 0, :]

def get_embeddings_in_batches(texts, tokenizer, model, batch_size=100):
    embeddings = []
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        inputs = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True).to('cuda')
        with torch.no_grad():
            outputs = model(**inputs)
        batch_embeddings = outputs.last_hidden_state[:, 0, :]
        embeddings.append(batch_embeddings)
    return torch.cat(embeddings)

# %%
from scipy.spatial.distance import cosine
import numpy as np

# kosinus benzerliğini hesaplama işlevi
def calculate_similarity(embedding1, embedding2):
    # kosinus mesafesi benzerliğin tersi oldugundan bu nedenle 1-cosine(embedding1, embedding2) olarak hesaplıyoruz
    similarity = 1 - cosine(embedding1, embedding2)
    return similarity

# %%
# top-1 ve top-5 başarı oranı hesaplama islevi
def calculate_top_k_success(questions, answers, tokenizer, model, batch_size=400, k=5):
    top1_count = 0
    top5_count = 0
    for idx, question in enumerate(questions):
        question_embedding = get_embeddings([question], tokenizer, model)[0].cpu().numpy()
        # tum cevapların embedding'lerini hesaplayalım

        similarities = []
        for i in range(0, len(answers), batch_size):
            batch_answers = answers[i:i + batch_size]
            batch_answer_embeddings = get_embeddings(batch_answers, tokenizer, model).cpu().numpy()

            # Soru ile bu parti arasındaki benzerlik skorlarını hesapla
            batch_similarities = [calculate_similarity(question_embedding, answer) for answer in batch_answer_embeddings]
            similarities.extend(batch_similarities)


        sorted_indices = np.argsort(similarities)[::-1]
        top_k_indices = sorted_indices[:k]

        # gercek cevabın indeksi k içerisinde ise sayacı arttıralım
        # idx = index
        if idx in top_k_indices:
            top5_count += 1
            if top_k_indices[0] == idx:
                top1_count += 1
        # ilk seferde calisip calismadigindan emin olmak icin step sayaci koydum bundan sonraki tum modellerde bu sayaci 50 ser 50 ser arttiriyorum cok fazla otuput olmamasi icin
        print('Step Complete - Index:',idx)
    top1_success_rate = top1_count / len(questions)
    top5_success_rate = top5_count / len(questions)

    return top1_success_rate, top5_success_rate

# %%
# Model 1 - KaLM-embedding-multilingual-mini-v1
# Model 2 - pingkeest/learning2_model
# Model 3 - sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Model 4 - Alibaba-NLP/gte-multilingual-base
# Model 5 - Alibaba-NLP/gte-large-en-v1.5
# Model 6 - dbmdz/bert-base-turkish-cased

# kullanilacak model isimlerinin listesi
# ilk basta planim sirayla modelleri calistirmakti ancak uzun surmesinden oturu paralel olarak modelleri boldum
# ve kodu bir bir her model icin parelel olarak calistirdim
custom_model_names = [
    "HIT-TMG/KaLM-embedding-multilingual-mini-v1"
]

# her model için top-1 ve top-5 başarı oranlarını hesaplayalım
results = {}
for model_name in custom_model_names:
    print(f"Model: {model_name} yükleniyor...")
    tokenizer, model = get_model_and_tokenizer(model_name)

    print(f"{model_name} için top-1 ve top-5 başarı oranları hesaplanıyor...")
    top1_rate, top5_rate = calculate_top_k_success(selected_questions, selected_answers, tokenizer, model)

    results[model_name] = {
        "top1": top1_rate,
        "top5": top5_rate
    }

    print(f"{model_name} - Top-1 Başarı Oranı: {top1_rate:.2%}, Top-5 Başarı Oranı: {top5_rate:.2%}\n")
# Out:
# Model: HIT-TMG/KaLM-embedding-multilingual-mini-v1 yükleniyor...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/80.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/370 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/824 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# HIT-TMG/KaLM-embedding-multilingual-mini-v1 için top-1 ve top-5 başarı oranları hesaplanıyor...
# Step Complete - Index: 0
# Step Complete - Index: 1
# Step Complete - Index: 2
# Step Complete - Index: 3
# Step Complete - Index: 4
# Step Complete - Index: 5
# Step Complete - Index: 6
# Step Complete - Index: 7
# Step Complete - Index: 8
# Step Complete - Index: 9
# Step Complete - Index: 10
# Step Complete - Index: 11
# Step Complete - Index: 12
# Step Complete - Index: 13
# Step Complete - Index: 14
# Step Complete - Index: 15
# Step Complete - Index: 16
# Step Complete - Index: 17
# Step Complete - Index: 18
# Step Complete - Index: 19
# Step Complete - Index: 20
# Step Complete - Index: 21
# Step Complete - Index: 22
# Step Complete - Index: 23
# Step Complete - Index: 24
# Step Complete - Index: 25
# Step Complete - Index: 26
# Step Complete - Index: 27
# Step Complete - Index: 28
# Step Complete - Index: 29
# Step Complete - Index: 30
# Step Complete - Index: 31
# Step Complete - Index: 32
# Step Complete - Index: 33
# Step Complete - Index: 34
# Step Complete - Index: 35
# Step Complete - Index: 36
# Step Complete - Index: 37
# Step Complete - Index: 38
# Step Complete - Index: 39
# Step Complete - Index: 40
# Step Complete - Index: 41
# Step Complete - Index: 42
# Step Complete - Index: 43
# Step Complete - Index: 44
# Step Complete - Index: 45
# Step Complete - Index: 46
# Step Complete - Index: 47
# Step Complete - Index: 48
# Step Complete - Index: 49
# Step Complete - Index: 50
# Step Complete - Index: 51
# Step Complete - Index: 52
# Step Complete - Index: 53
# Step Complete - Index: 54
# Step Complete - Index: 55
# Step Complete - Index: 56
# Step Complete - Index: 57
# Step Complete - Index: 58
# Step Complete - Index: 59
# Step Complete - Index: 60
# Step Complete - Index: 61
# Step Complete - Index: 62
# Step Complete - Index: 63
# Step Complete - Index: 64
# Step Complete - Index: 65
# Step Complete - Index: 66
# Step Complete - Index: 67
# Step Complete - Index: 68
# Step Complete - Index: 69
# Step Complete - Index: 70
# Step Complete - Index: 71
# Step Complete - Index: 72
# Step Complete - Index: 73
# Step Complete - Index: 74
# Step Complete - Index: 75
# Step Complete - Index: 76
# Step Complete - Index: 77
# Step Complete - Index: 78
# Step Complete - Index: 79
# Step Complete - Index: 80
# Step Complete - Index: 81
# Step Complete - Index: 82
# Step Complete - Index: 83
# Step Complete - Index: 84
# Step Complete - Index: 85
# Step Complete - Index: 86
# Step Complete - Index: 87
# Step Complete - Index: 88
# Step Complete - Index: 89
# Step Complete - Index: 90
# Step Complete - Index: 91
# Step Complete - Index: 92
# Step Complete - Index: 93
# Step Complete - Index: 94
# Step Complete - Index: 95
# Step Complete - Index: 96
# Step Complete - Index: 97
# Step Complete - Index: 98
# Step Complete - Index: 99
# Step Complete - Index: 100
# Step Complete - Index: 101
# Step Complete - Index: 102
# Step Complete - Index: 103
# Step Complete - Index: 104
# Step Complete - Index: 105
# Step Complete - Index: 106
# Step Complete - Index: 107
# Step Complete - Index: 108
# Step Complete - Index: 109
# Step Complete - Index: 110
# Step Complete - Index: 111
# Step Complete - Index: 112
# Step Complete - Index: 113
# Step Complete - Index: 114
# Step Complete - Index: 115
# Step Complete - Index: 116
# Step Complete - Index: 117
# Step Complete - Index: 118
# Step Complete - Index: 119
# Step Complete - Index: 120
# Step Complete - Index: 121
# Step Complete - Index: 122
# Step Complete - Index: 123
# Step Complete - Index: 124
# Step Complete - Index: 125
# Step Complete - Index: 126
# Step Complete - Index: 127
# Step Complete - Index: 128
# Step Complete - Index: 129
# Step Complete - Index: 130
# Step Complete - Index: 131
# Step Complete - Index: 132
# Step Complete - Index: 133
# Step Complete - Index: 134
# Step Complete - Index: 135
# Step Complete - Index: 136
# Step Complete - Index: 137
# Step Complete - Index: 138
# Step Complete - Index: 139
# Step Complete - Index: 140
# Step Complete - Index: 141
# Step Complete - Index: 142
# Step Complete - Index: 143
# Step Complete - Index: 144
# Step Complete - Index: 145
# Step Complete - Index: 146
# Step Complete - Index: 147
# Step Complete - Index: 148
# Step Complete - Index: 149
# Step Complete - Index: 150
# Step Complete - Index: 151
# Step Complete - Index: 152
# Step Complete - Index: 153
# Step Complete - Index: 154
# Step Complete - Index: 155
# Step Complete - Index: 156
# Step Complete - Index: 157
# Step Complete - Index: 158
# Step Complete - Index: 159
# Step Complete - Index: 160
# Step Complete - Index: 161
# Step Complete - Index: 162
# Step Complete - Index: 163
# Step Complete - Index: 164
# Step Complete - Index: 165
# Step Complete - Index: 166
# Step Complete - Index: 167
# Step Complete - Index: 168
# Step Complete - Index: 169
# Step Complete - Index: 170
# Step Complete - Index: 171
# Step Complete - Index: 172
# Step Complete - Index: 173
# Step Complete - Index: 174
# Step Complete - Index: 175
# Step Complete - Index: 176
# Step Complete - Index: 177
# Step Complete - Index: 178
# Step Complete - Index: 179
# Step Complete - Index: 180
# Step Complete - Index: 181
# Step Complete - Index: 182
# Step Complete - Index: 183
# Step Complete - Index: 184
# Step Complete - Index: 185
# Step Complete - Index: 186
# Step Complete - Index: 187
# Step Complete - Index: 188
# Step Complete - Index: 189
# Step Complete - Index: 190
# Step Complete - Index: 191
# Step Complete - Index: 192
# Step Complete - Index: 193
# Step Complete - Index: 194
# Step Complete - Index: 195
# Step Complete - Index: 196
# Step Complete - Index: 197
# Step Complete - Index: 198
# Step Complete - Index: 199
# Step Complete - Index: 200
# Step Complete - Index: 201
# Step Complete - Index: 202
# Step Complete - Index: 203
# Step Complete - Index: 204
# Step Complete - Index: 205
# Step Complete - Index: 206
# Step Complete - Index: 207
# Step Complete - Index: 208
# Step Complete - Index: 209
# Step Complete - Index: 210
# Step Complete - Index: 211
# Step Complete - Index: 212
# Step Complete - Index: 213
# Step Complete - Index: 214
# Step Complete - Index: 215
# Step Complete - Index: 216
# Step Complete - Index: 217
# Step Complete - Index: 218
# Step Complete - Index: 219
# Step Complete - Index: 220
# Step Complete - Index: 221
# Step Complete - Index: 222
# Step Complete - Index: 223
# Step Complete - Index: 224
# Step Complete - Index: 225
# Step Complete - Index: 226
# Step Complete - Index: 227
# Step Complete - Index: 228
# Step Complete - Index: 229
# Step Complete - Index: 230
# Step Complete - Index: 231
# Step Complete - Index: 232
# Step Complete - Index: 233
# Step Complete - Index: 234
# Step Complete - Index: 235
# Step Complete - Index: 236
# Step Complete - Index: 237
# Step Complete - Index: 238
# Step Complete - Index: 239
# Step Complete - Index: 240
# Step Complete - Index: 241
# Step Complete - Index: 242
# Step Complete - Index: 243
# Step Complete - Index: 244
# Step Complete - Index: 245
# Step Complete - Index: 246
# Step Complete - Index: 247
# Step Complete - Index: 248
# Step Complete - Index: 249
# Step Complete - Index: 250
# Step Complete - Index: 251
# Step Complete - Index: 252
# Step Complete - Index: 253
# Step Complete - Index: 254
# Step Complete - Index: 255
# Step Complete - Index: 256
# Step Complete - Index: 257
# Step Complete - Index: 258
# Step Complete - Index: 259
# Step Complete - Index: 260
# Step Complete - Index: 261
# Step Complete - Index: 262
# Step Complete - Index: 263
# Step Complete - Index: 264
# Step Complete - Index: 265
# Step Complete - Index: 266
# Step Complete - Index: 267
# Step Complete - Index: 268
# Step Complete - Index: 269
# Step Complete - Index: 270
# Step Complete - Index: 271
# Step Complete - Index: 272
# Step Complete - Index: 273
# Step Complete - Index: 274
# Step Complete - Index: 275
# Step Complete - Index: 276
# Step Complete - Index: 277
# Step Complete - Index: 278
# Step Complete - Index: 279
# Step Complete - Index: 280
# Step Complete - Index: 281
# Step Complete - Index: 282
# Step Complete - Index: 283
# Step Complete - Index: 284
# Step Complete - Index: 285
# Step Complete - Index: 286
# Step Complete - Index: 287
# Step Complete - Index: 288
# Step Complete - Index: 289
# Step Complete - Index: 290
# Step Complete - Index: 291
# Step Complete - Index: 292
# Step Complete - Index: 293
# Step Complete - Index: 294
# Step Complete - Index: 295
# Step Complete - Index: 296
# Step Complete - Index: 297
# Step Complete - Index: 298
# Step Complete - Index: 299
# Step Complete - Index: 300
# Step Complete - Index: 301
# Step Complete - Index: 302
# Step Complete - Index: 303
# Step Complete - Index: 304
# Step Complete - Index: 305
# Step Complete - Index: 306
# Step Complete - Index: 307
# Step Complete - Index: 308
# Step Complete - Index: 309
# Step Complete - Index: 310
# Step Complete - Index: 311
# Step Complete - Index: 312
# Step Complete - Index: 313
# Step Complete - Index: 314
# Step Complete - Index: 315
# Step Complete - Index: 316
# Step Complete - Index: 317
# Step Complete - Index: 318
# Step Complete - Index: 319
# Step Complete - Index: 320
# Step Complete - Index: 321
# Step Complete - Index: 322
# Step Complete - Index: 323
# Step Complete - Index: 324
# Step Complete - Index: 325
# Step Complete - Index: 326
# Step Complete - Index: 327
# Step Complete - Index: 328
# Step Complete - Index: 329
# Step Complete - Index: 330
# Step Complete - Index: 331
# Step Complete - Index: 332
# Step Complete - Index: 333
# Step Complete - Index: 334
# Step Complete - Index: 335
# Step Complete - Index: 336
# Step Complete - Index: 337
# Step Complete - Index: 338
# Step Complete - Index: 339
# Step Complete - Index: 340
# Step Complete - Index: 341
# Step Complete - Index: 342
# Step Complete - Index: 343
# Step Complete - Index: 344
# Step Complete - Index: 345
# Step Complete - Index: 346
# Step Complete - Index: 347
# Step Complete - Index: 348
# Step Complete - Index: 349
# Step Complete - Index: 350
# Step Complete - Index: 351
# Step Complete - Index: 352
# Step Complete - Index: 353
# Step Complete - Index: 354
# Step Complete - Index: 355
# Step Complete - Index: 356
# Step Complete - Index: 357
# Step Complete - Index: 358
# Step Complete - Index: 359
# Step Complete - Index: 360
# Step Complete - Index: 361
# Step Complete - Index: 362
# Step Complete - Index: 363
# Step Complete - Index: 364
# Step Complete - Index: 365
# Step Complete - Index: 366
# Step Complete - Index: 367
# Step Complete - Index: 368
# Step Complete - Index: 369
# Step Complete - Index: 370
# Step Complete - Index: 371
# Step Complete - Index: 372
# Step Complete - Index: 373
# Step Complete - Index: 374
# Step Complete - Index: 375
# Step Complete - Index: 376
# Step Complete - Index: 377
# Step Complete - Index: 378
# Step Complete - Index: 379
# Step Complete - Index: 380
# Step Complete - Index: 381
# Step Complete - Index: 382
# Step Complete - Index: 383
# Step Complete - Index: 384
# Step Complete - Index: 385
# Step Complete - Index: 386
# Step Complete - Index: 387
# Step Complete - Index: 388
# Step Complete - Index: 389
# Step Complete - Index: 390
# Step Complete - Index: 391
# Step Complete - Index: 392
# Step Complete - Index: 393
# Step Complete - Index: 394
# Step Complete - Index: 395
# Step Complete - Index: 396
# Step Complete - Index: 397
# Step Complete - Index: 398
# Step Complete - Index: 399
# Step Complete - Index: 400
# Step Complete - Index: 401
# Step Complete - Index: 402
# Step Complete - Index: 403
# Step Complete - Index: 404
# Step Complete - Index: 405
# Step Complete - Index: 406
# Step Complete - Index: 407
# Step Complete - Index: 408
# Step Complete - Index: 409
# Step Complete - Index: 410
# Step Complete - Index: 411
# Step Complete - Index: 412
# Step Complete - Index: 413
# Step Complete - Index: 414
# Step Complete - Index: 415
# Step Complete - Index: 416
# Step Complete - Index: 417
# Step Complete - Index: 418
# Step Complete - Index: 419
# Step Complete - Index: 420
# Step Complete - Index: 421
# Step Complete - Index: 422
# Step Complete - Index: 423
# Step Complete - Index: 424
# Step Complete - Index: 425
# Step Complete - Index: 426
# Step Complete - Index: 427
# Step Complete - Index: 428
# Step Complete - Index: 429
# Step Complete - Index: 430
# Step Complete - Index: 431
# Step Complete - Index: 432
# Step Complete - Index: 433
# Step Complete - Index: 434
# Step Complete - Index: 435
# Step Complete - Index: 436
# Step Complete - Index: 437
# Step Complete - Index: 438
# Step Complete - Index: 439
# Step Complete - Index: 440
# Step Complete - Index: 441
# Step Complete - Index: 442
# Step Complete - Index: 443
# Step Complete - Index: 444
# Step Complete - Index: 445
# Step Complete - Index: 446
# Step Complete - Index: 447
# Step Complete - Index: 448
# Step Complete - Index: 449
# Step Complete - Index: 450
# Step Complete - Index: 451
# Step Complete - Index: 452
# Step Complete - Index: 453
# Step Complete - Index: 454
# Step Complete - Index: 455
# Step Complete - Index: 456
# Step Complete - Index: 457
# Step Complete - Index: 458
# Step Complete - Index: 459
# Step Complete - Index: 460
# Step Complete - Index: 461
# Step Complete - Index: 462
# Step Complete - Index: 463
# Step Complete - Index: 464
# Step Complete - Index: 465
# Step Complete - Index: 466
# Step Complete - Index: 467
# Step Complete - Index: 468
# Step Complete - Index: 469
# Step Complete - Index: 470
# Step Complete - Index: 471
# Step Complete - Index: 472
# Step Complete - Index: 473
# Step Complete - Index: 474
# Step Complete - Index: 475
# Step Complete - Index: 476
# Step Complete - Index: 477
# Step Complete - Index: 478
# Step Complete - Index: 479
# Step Complete - Index: 480
# Step Complete - Index: 481
# Step Complete - Index: 482
# Step Complete - Index: 483
# Step Complete - Index: 484
# Step Complete - Index: 485
# Step Complete - Index: 486
# Step Complete - Index: 487
# Step Complete - Index: 488
# Step Complete - Index: 489
# Step Complete - Index: 490
# Step Complete - Index: 491
# Step Complete - Index: 492
# Step Complete - Index: 493
# Step Complete - Index: 494
# Step Complete - Index: 495
# Step Complete - Index: 496
# Step Complete - Index: 497
# Step Complete - Index: 498
# Step Complete - Index: 499
# Step Complete - Index: 500
# Step Complete - Index: 501
# Step Complete - Index: 502
# Step Complete - Index: 503
# Step Complete - Index: 504
# Step Complete - Index: 505
# Step Complete - Index: 506
# Step Complete - Index: 507
# Step Complete - Index: 508
# Step Complete - Index: 509
# Step Complete - Index: 510
# Step Complete - Index: 511
# Step Complete - Index: 512
# Step Complete - Index: 513
# Step Complete - Index: 514
# Step Complete - Index: 515
# Step Complete - Index: 516
# Step Complete - Index: 517
# Step Complete - Index: 518
# Step Complete - Index: 519
# Step Complete - Index: 520
# Step Complete - Index: 521
# Step Complete - Index: 522
# Step Complete - Index: 523
# Step Complete - Index: 524
# Step Complete - Index: 525
# Step Complete - Index: 526
# Step Complete - Index: 527
# Step Complete - Index: 528
# Step Complete - Index: 529
# Step Complete - Index: 530
# Step Complete - Index: 531
# Step Complete - Index: 532
# Step Complete - Index: 533
# Step Complete - Index: 534
# Step Complete - Index: 535
# Step Complete - Index: 536
# Step Complete - Index: 537
# Step Complete - Index: 538
# Step Complete - Index: 539
# Step Complete - Index: 540
# Step Complete - Index: 541
# Step Complete - Index: 542
# Step Complete - Index: 543
# Step Complete - Index: 544
# Step Complete - Index: 545
# Step Complete - Index: 546
# Step Complete - Index: 547
# Step Complete - Index: 548
# Step Complete - Index: 549
# Step Complete - Index: 550
# Step Complete - Index: 551
# Step Complete - Index: 552
# Step Complete - Index: 553
# Step Complete - Index: 554
# Step Complete - Index: 555
# Step Complete - Index: 556
# Step Complete - Index: 557
# Step Complete - Index: 558
# Step Complete - Index: 559
# Step Complete - Index: 560
# Step Complete - Index: 561
# Step Complete - Index: 562
# Step Complete - Index: 563
# Step Complete - Index: 564
# Step Complete - Index: 565
# Step Complete - Index: 566
# Step Complete - Index: 567
# Step Complete - Index: 568
# Step Complete - Index: 569
# Step Complete - Index: 570
# Step Complete - Index: 571
# Step Complete - Index: 572
# Step Complete - Index: 573
# Step Complete - Index: 574
# Step Complete - Index: 575
# Step Complete - Index: 576
# Step Complete - Index: 577
# Step Complete - Index: 578
# Step Complete - Index: 579
# Step Complete - Index: 580
# Step Complete - Index: 581
# Step Complete - Index: 582
# Step Complete - Index: 583
# Step Complete - Index: 584
# Step Complete - Index: 585
# Step Complete - Index: 586
# Step Complete - Index: 587
# Step Complete - Index: 588
# Step Complete - Index: 589
# Step Complete - Index: 590
# Step Complete - Index: 591
# Step Complete - Index: 592
# Step Complete - Index: 593
# Step Complete - Index: 594
# Step Complete - Index: 595
# Step Complete - Index: 596
# Step Complete - Index: 597
# Step Complete - Index: 598
# Step Complete - Index: 599
# Step Complete - Index: 600
# Step Complete - Index: 601
# Step Complete - Index: 602
# Step Complete - Index: 603
# Step Complete - Index: 604
# Step Complete - Index: 605
# Step Complete - Index: 606
# Step Complete - Index: 607
# Step Complete - Index: 608
# Step Complete - Index: 609
# Step Complete - Index: 610
# Step Complete - Index: 611
# Step Complete - Index: 612
# Step Complete - Index: 613
# Step Complete - Index: 614
# Step Complete - Index: 615
# Step Complete - Index: 616
# Step Complete - Index: 617
# Step Complete - Index: 618
# Step Complete - Index: 619
# Step Complete - Index: 620
# Step Complete - Index: 621
# Step Complete - Index: 622
# Step Complete - Index: 623
# Step Complete - Index: 624
# Step Complete - Index: 625
# Step Complete - Index: 626
# Step Complete - Index: 627
# Step Complete - Index: 628
# Step Complete - Index: 629
# Step Complete - Index: 630
# Step Complete - Index: 631
# Step Complete - Index: 632
# Step Complete - Index: 633
# Step Complete - Index: 634
# Step Complete - Index: 635
# Step Complete - Index: 636
# Step Complete - Index: 637
# Step Complete - Index: 638
# Step Complete - Index: 639
# Step Complete - Index: 640
# Step Complete - Index: 641
# Step Complete - Index: 642
# Step Complete - Index: 643
# Step Complete - Index: 644
# Step Complete - Index: 645
# Step Complete - Index: 646
# Step Complete - Index: 647
# Step Complete - Index: 648
# Step Complete - Index: 649
# Step Complete - Index: 650
# Step Complete - Index: 651
# Step Complete - Index: 652
# Step Complete - Index: 653
# Step Complete - Index: 654
# Step Complete - Index: 655
# Step Complete - Index: 656
# Step Complete - Index: 657
# Step Complete - Index: 658
# Step Complete - Index: 659
# Step Complete - Index: 660
# Step Complete - Index: 661
# Step Complete - Index: 662
# Step Complete - Index: 663
# Step Complete - Index: 664
# Step Complete - Index: 665
# Step Complete - Index: 666
# Step Complete - Index: 667
# Step Complete - Index: 668
# Step Complete - Index: 669
# Step Complete - Index: 670
# Step Complete - Index: 671
# Step Complete - Index: 672
# Step Complete - Index: 673
# Step Complete - Index: 674
# Step Complete - Index: 675
# Step Complete - Index: 676
# Step Complete - Index: 677
# Step Complete - Index: 678
# Step Complete - Index: 679
# Step Complete - Index: 680
# Step Complete - Index: 681
# Step Complete - Index: 682
# Step Complete - Index: 683
# Step Complete - Index: 684
# Step Complete - Index: 685
# Step Complete - Index: 686
# Step Complete - Index: 687
# Step Complete - Index: 688
# Step Complete - Index: 689
# Step Complete - Index: 690
# Step Complete - Index: 691
# Step Complete - Index: 692
# Step Complete - Index: 693
# Step Complete - Index: 694
# Step Complete - Index: 695
# Step Complete - Index: 696
# Step Complete - Index: 697
# Step Complete - Index: 698
# Step Complete - Index: 699
# Step Complete - Index: 700
# Step Complete - Index: 701
# Step Complete - Index: 702
# Step Complete - Index: 703
# Step Complete - Index: 704
# Step Complete - Index: 705
# Step Complete - Index: 706
# Step Complete - Index: 707
# Step Complete - Index: 708
# Step Complete - Index: 709
# Step Complete - Index: 710
# Step Complete - Index: 711
# Step Complete - Index: 712
# Step Complete - Index: 713
# Step Complete - Index: 714
# Step Complete - Index: 715
# Step Complete - Index: 716
# Step Complete - Index: 717
# Step Complete - Index: 718
# Step Complete - Index: 719
# Step Complete - Index: 720
# Step Complete - Index: 721
# Step Complete - Index: 722
# Step Complete - Index: 723
# Step Complete - Index: 724
# Step Complete - Index: 725
# Step Complete - Index: 726
# Step Complete - Index: 727
# Step Complete - Index: 728
# Step Complete - Index: 729
# Step Complete - Index: 730
# Step Complete - Index: 731
# Step Complete - Index: 732
# Step Complete - Index: 733
# Step Complete - Index: 734
# Step Complete - Index: 735
# Step Complete - Index: 736
# Step Complete - Index: 737
# Step Complete - Index: 738
# Step Complete - Index: 739
# Step Complete - Index: 740
# Step Complete - Index: 741
# Step Complete - Index: 742
# Step Complete - Index: 743
# Step Complete - Index: 744
# Step Complete - Index: 745
# Step Complete - Index: 746
# Step Complete - Index: 747
# Step Complete - Index: 748
# Step Complete - Index: 749
# Step Complete - Index: 750
# Step Complete - Index: 751
# Step Complete - Index: 752
# Step Complete - Index: 753
# Step Complete - Index: 754
# Step Complete - Index: 755
# Step Complete - Index: 756
# Step Complete - Index: 757
# Step Complete - Index: 758
# Step Complete - Index: 759
# Step Complete - Index: 760
# Step Complete - Index: 761
# Step Complete - Index: 762
# Step Complete - Index: 763
# Step Complete - Index: 764
# Step Complete - Index: 765
# Step Complete - Index: 766
# Step Complete - Index: 767
# Step Complete - Index: 768
# Step Complete - Index: 769
# Step Complete - Index: 770
# Step Complete - Index: 771
# Step Complete - Index: 772
# Step Complete - Index: 773
# Step Complete - Index: 774
# Step Complete - Index: 775
# Step Complete - Index: 776
# Step Complete - Index: 777
# Step Complete - Index: 778
# Step Complete - Index: 779
# Step Complete - Index: 780
# Step Complete - Index: 781
# Step Complete - Index: 782
# Step Complete - Index: 783
# Step Complete - Index: 784
# Step Complete - Index: 785
# Step Complete - Index: 786
# Step Complete - Index: 787
# Step Complete - Index: 788
# Step Complete - Index: 789
# Step Complete - Index: 790
# Step Complete - Index: 791
# Step Complete - Index: 792
# Step Complete - Index: 793
# Step Complete - Index: 794
# Step Complete - Index: 795
# Step Complete - Index: 796
# Step Complete - Index: 797
# Step Complete - Index: 798
# Step Complete - Index: 799
# Step Complete - Index: 800
# Step Complete - Index: 801
# Step Complete - Index: 802
# Step Complete - Index: 803
# Step Complete - Index: 804
# Step Complete - Index: 805
# Step Complete - Index: 806
# Step Complete - Index: 807
# Step Complete - Index: 808
# Step Complete - Index: 809
# Step Complete - Index: 810
# Step Complete - Index: 811
# Step Complete - Index: 812
# Step Complete - Index: 813
# Step Complete - Index: 814
# Step Complete - Index: 815
# Step Complete - Index: 816
# Step Complete - Index: 817
# Step Complete - Index: 818
# Step Complete - Index: 819
# Step Complete - Index: 820
# Step Complete - Index: 821
# Step Complete - Index: 822
# Step Complete - Index: 823
# Step Complete - Index: 824
# Step Complete - Index: 825
# Step Complete - Index: 826
# Step Complete - Index: 827
# Step Complete - Index: 828
# Step Complete - Index: 829
# Step Complete - Index: 830
# Step Complete - Index: 831
# Step Complete - Index: 832
# Step Complete - Index: 833
# Step Complete - Index: 834
# Step Complete - Index: 835
# Step Complete - Index: 836
# Step Complete - Index: 837
# Step Complete - Index: 838
# Step Complete - Index: 839
# Step Complete - Index: 840
# Step Complete - Index: 841
# Step Complete - Index: 842
# Step Complete - Index: 843
# Step Complete - Index: 844
# Step Complete - Index: 845
# Step Complete - Index: 846
# Step Complete - Index: 847
# Step Complete - Index: 848
# Step Complete - Index: 849
# Step Complete - Index: 850
# Step Complete - Index: 851
# Step Complete - Index: 852
# Step Complete - Index: 853
# Step Complete - Index: 854
# Step Complete - Index: 855
# Step Complete - Index: 856
# Step Complete - Index: 857
# Step Complete - Index: 858
# Step Complete - Index: 859
# Step Complete - Index: 860
# Step Complete - Index: 861
# Step Complete - Index: 862
# Step Complete - Index: 863
# Step Complete - Index: 864
# Step Complete - Index: 865
# Step Complete - Index: 866
# Step Complete - Index: 867
# Step Complete - Index: 868
# Step Complete - Index: 869
# Step Complete - Index: 870
# Step Complete - Index: 871
# Step Complete - Index: 872
# Step Complete - Index: 873
# Step Complete - Index: 874
# Step Complete - Index: 875
# Step Complete - Index: 876
# Step Complete - Index: 877
# Step Complete - Index: 878
# Step Complete - Index: 879
# Step Complete - Index: 880
# Step Complete - Index: 881
# Step Complete - Index: 882
# Step Complete - Index: 883
# Step Complete - Index: 884
# Step Complete - Index: 885
# Step Complete - Index: 886
# Step Complete - Index: 887
# Step Complete - Index: 888
# Step Complete - Index: 889
# Step Complete - Index: 890
# Step Complete - Index: 891
# Step Complete - Index: 892
# Step Complete - Index: 893
# Step Complete - Index: 894
# Step Complete - Index: 895
# Step Complete - Index: 896
# Step Complete - Index: 897
# Step Complete - Index: 898
# Step Complete - Index: 899
# Step Complete - Index: 900
# Step Complete - Index: 901
# Step Complete - Index: 902
# Step Complete - Index: 903
# Step Complete - Index: 904
# Step Complete - Index: 905
# Step Complete - Index: 906
# Step Complete - Index: 907
# Step Complete - Index: 908
# Step Complete - Index: 909
# Step Complete - Index: 910
# Step Complete - Index: 911
# Step Complete - Index: 912
# Step Complete - Index: 913
# Step Complete - Index: 914
# Step Complete - Index: 915
# Step Complete - Index: 916
# Step Complete - Index: 917
# Step Complete - Index: 918
# Step Complete - Index: 919
# Step Complete - Index: 920
# Step Complete - Index: 921
# Step Complete - Index: 922
# Step Complete - Index: 923
# Step Complete - Index: 924
# Step Complete - Index: 925
# Step Complete - Index: 926
# Step Complete - Index: 927
# Step Complete - Index: 928
# Step Complete - Index: 929
# Step Complete - Index: 930
# Step Complete - Index: 931
# Step Complete - Index: 932
# Step Complete - Index: 933
# Step Complete - Index: 934
# Step Complete - Index: 935
# Step Complete - Index: 936
# Step Complete - Index: 937
# Step Complete - Index: 938
# Step Complete - Index: 939
# Step Complete - Index: 940
# Step Complete - Index: 941
# Step Complete - Index: 942
# Step Complete - Index: 943
# Step Complete - Index: 944
# Step Complete - Index: 945
# Step Complete - Index: 946
# Step Complete - Index: 947
# Step Complete - Index: 948
# Step Complete - Index: 949
# Step Complete - Index: 950
# Step Complete - Index: 951
# Step Complete - Index: 952
# Step Complete - Index: 953
# Step Complete - Index: 954
# Step Complete - Index: 955
# Step Complete - Index: 956
# Step Complete - Index: 957
# Step Complete - Index: 958
# Step Complete - Index: 959
# Step Complete - Index: 960
# Step Complete - Index: 961
# Step Complete - Index: 962
# Step Complete - Index: 963
# Step Complete - Index: 964
# Step Complete - Index: 965
# Step Complete - Index: 966
# Step Complete - Index: 967
# Step Complete - Index: 968
# Step Complete - Index: 969
# Step Complete - Index: 970
# Step Complete - Index: 971
# Step Complete - Index: 972
# Step Complete - Index: 973
# Step Complete - Index: 974
# Step Complete - Index: 975
# Step Complete - Index: 976
# Step Complete - Index: 977
# Step Complete - Index: 978
# Step Complete - Index: 979
# Step Complete - Index: 980
# Step Complete - Index: 981
# Step Complete - Index: 982
# Step Complete - Index: 983
# Step Complete - Index: 984
# Step Complete - Index: 985
# Step Complete - Index: 986
# Step Complete - Index: 987
# Step Complete - Index: 988
# Step Complete - Index: 989
# Step Complete - Index: 990
# Step Complete - Index: 991
# Step Complete - Index: 992
# Step Complete - Index: 993
# Step Complete - Index: 994
# Step Complete - Index: 995
# Step Complete - Index: 996
# Step Complete - Index: 997
# Step Complete - Index: 998
# Step Complete - Index: 999
# HIT-TMG/KaLM-embedding-multilingual-mini-v1 - Top-1 Başarı Oranı: 0.30%, Top-5 Başarı Oranı: 1.00%

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# t-SNE uygulayarak gorsellestirdim
def plot_tsne(embeddings, labels, title):
    tsne = TSNE(n_components=2, random_state=42)
    reduced_embeddings = tsne.fit_transform(embeddings)
    colors = ['blue' if label == 'question' else 'red' for label in labels]
    plt.figure(figsize=(10, 8))
    plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], c=colors, alpha=0.5)
    plt.title(title)
    plt.xlabel('t-SNE Dim 1')
    plt.ylabel('t-SNE Dim 2')
    plt.show()

for model_name in custom_model_names:
    print(f"{model_name} için t-SNE görselleştirmesi oluşturuluyor...")
    tokenizer, model = get_model_and_tokenizer(model_name)

    # embedding alma
    question_embeddings = get_embeddings_in_batches(selected_questions, tokenizer, model).cpu().numpy()
    answer_embeddings = get_embeddings_in_batches(selected_answers, tokenizer, model).cpu().numpy()

    # t-SNE icin verileri birlestirme
    all_embeddings = np.vstack((question_embeddings, answer_embeddings))
    labels = ['question'] * len(selected_questions) + ['answer'] * len(selected_answers)

    # gorsellestirme
    plot_tsne(all_embeddings, labels, f"{model_name} t-SNE Visualization")
# Out:
# HIT-TMG/KaLM-embedding-multilingual-mini-v1 için t-SNE görselleştirmesi oluşturuluyor...
